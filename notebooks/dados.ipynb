# %% [markdown]
#                                         NOTEBOOK PARA ANÁLISE DE DADOS PROJETO-FINAL-ICD

# %%
import pandas as pd
#import numpy as np
#import seaborn as sns
#import matplotlib.pyplot as plt

# %% [markdown]
#                                     LENDO OS ARQUIVOS CSV E OS TRANSFORMANDO EM DATAFRAMES

# %%
data = pd.read_csv(r"/home/vinicius_olzon/Documents/Projeto-Final-ICD/tcc_ceds_music.csv")
df = pd.DataFrame(data)

# %%
#arrumar os topicos de acordo com os novos nomes das colunas
df.rename(columns={"artist_name":"Artista","track_name":"Música","release_date":"Ano","genre":"Gênero","lyrics":"Letras",
"len":"Duração","dating":"Namoro","violence":"Violência","world/life":"Vida","night/time":"Noturno",'shake the audience':"Balança Audiência",
'family/gospel':"Gospel", 'romantic':"Romântico", 'communication':"Comunicação", 'obscene':"Obsceno", 'music':"Musical",
'movement/places':"Lugares", 'light/visual perceptions':"Percepções Visuais", 'family/spiritual':"Espiritual",
'like/girls':"Garotas", 'sadness':"Tristeza", 'feelings':"Sentimentos", 'danceability':"Dançabilidade", 'loudness':"Altura",
'acousticness':"Acusticidade", 'instrumentalness':"Instrumentalidade", 'valence':"Positividade", 'energy':"Energia", 'topic':"Tópico",
'age':"Idade"}, inplace = True)

df.head()
# Out:
#    Unnamed: 0               Artista                Música   Ano Gênero  \
# 0           0                mukesh  mohabbat bhi jhoothi  1950    pop
# 1           4         frankie laine             i believe  1950    pop
# 2           6           johnnie ray                   cry  1950    pop
# 3          10           pérez prado              patricia  1950    pop
# 4          12  giorgos papadopoulos    apopse eida oneiro  1950    pop
#
#                                               Letras  Duração    Namoro  \
# 0  hold time feel break feel untrue convince spea...       95  0.000598
# 1  believe drop rain fall grow believe darkest ni...       51  0.035537
# 2  sweetheart send letter goodbye secret feel bet...       24  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...       54  0.048249
# 4  till darling till matter know till dream live ...       48  0.001350
#
#    Violência      Vida  ...  Tristeza  Sentimentos  Dançabilidade    Altura  \
# ...
