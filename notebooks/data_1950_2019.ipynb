# %% [markdown]
#                                             NOTEBOOK PARA ANÁLISE DE DADOS PROJETO-FINAL-ICD

# %% [markdown]
#     Neste notebook são feitos os tratamentos necessários para o processamento dos dados. Aqui também são feitas diversas análises e gráficos que tratam mais profundamente sobre o conjunto de dados, todavia, já são feitas algumas conclusões sobre esses dados, tal como é obtido uma base para a resposta de algumas perguntas feitas anteriormente.

# %% [markdown]
# ## Bibliotecas utilizadas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Importando o csv e o transformando em um DataFrame

# %%
data = pd.read_csv(r"/home/vinicius_olzon/Documents/Programacao/Projeto_Final_ICD/1950-2019.csv")
df = pd.DataFrame(data)

# %% [markdown]
# ## Mostrando as 5 primeiras linhas do dataframe

# %%
df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
#    world/life  ...   sadness  feelings  danceability  loudness  acousticness  \
# 0    0.000598  ...  0.380299  0.117175      0.357739  0.454119      0.997992
# 1    0.443435  ...  0.001284  0.001284      0.331745  0.647540      0.954819
# 2    0.002770  ...  0.002770  0.225422      0.456298  0.585288      0.840361
# 3    0.001548  ...  0.225889  0.001548      0.686992  0.744404      0.083935
# 4    0.417772  ...  0.068800  0.001350      0.291671  0.646489      0.975904
#
#    instrumentalness   valence    energy       topic  age
# 0          0.901822  0.339448  0.137110     sadness  1.0
# 1          0.000002  0.325021  0.263240  world/life  1.0
# 2          0.000000  0.351814  0.139112       music  1.0
# 3          0.199393  0.775350  0.743736    romantic  1.0
# 4          0.000246  0.597073  0.394375    romantic  1.0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Análise e tratamento dos dados:
# Aqui foram retiradas algumas colunas que não são úteis para as análises a seguir, não somente, foi checado a existência de algum elemento nulo ou vazio.

# %%
unnecessary = ["Unnamed: 0", "len", "age", "release_date"]
df = df.drop(unnecessary, axis = 1)
df.isnull().values.any()
# Out:
# False

# %%
df.isna().values.any()
# Out:
# False

# %% [markdown]
# ## Medidas de centralidade e dispersão das características musicais

# %%
df.describe()
# Out:
#              dating      violence    world/life    night/time  \
# count  28372.000000  28372.000000  28372.000000  28372.000000
# mean       0.021112      0.118396      0.120973      0.057387
# std        0.052370      0.178684      0.172200      0.111923
# min        0.000291      0.000284      0.000291      0.000289
# 25%        0.000923      0.001120      0.001170      0.001032
# 50%        0.001462      0.002506      0.006579      0.001949
# 75%        0.004049      0.192608      0.197793      0.065842
# max        0.647706      0.981781      0.962105      0.973684
#
#        shake the audience  family/gospel      romantic  communication  \
# count        28372.000000   28372.000000  28372.000000   28372.000000
# mean             0.017422       0.017045      0.048681       0.076680
# std              0.040670       0.041966      0.106095       0.109538
# min              0.000284       0.000289      0.000284       0.000291
# 25%              0.000993       0.000923      0.000975       0.001144
# 50%              0.001595       0.001504      0.001754       0.002632
# 75%              0.010002       0.004785      0.042301       0.132136
# max              0.497463       0.545303      0.940789       0.645829
#
#             obscene         music  ...  family/spiritual    like/girls  \
# count  28372.000000  28372.000000  ...      28372.000000  28372.000000
# mean       0.097168      0.060047  ...          0.024150      0.028057
# std        0.181303      0.123329  ...          0.051025      0.058473
# min        0.000289      0.000289  ...          0.000284      0.000284
# 25%        0.001053      0.000975  ...          0.000957      0.000975
# 50%        0.001815      0.001815  ...          0.001645      0.001595
# 75%        0.088765      0.055101  ...          0.025498      0.026622
# max        0.992298      0.956938  ...          0.618073      0.594459
#
#             sadness      feelings  danceability      loudness  acousticness  \
# count  28372.000000  28372.000000  28372.000000  28372.000000  2.837200e+04
# mean       0.129389      0.030996      0.533348      0.665249  3.392347e-01
# std        0.181143      0.071652      0.173218      0.108434  3.267143e-01
# min        0.000284      0.000289      0.005415      0.000000  2.811248e-07
# 25%        0.001144      0.000993      0.412975      0.595364  3.423598e-02
# 50%        0.005263      0.001754      0.538612      0.679050  2.259028e-01
# 75%        0.235113      0.032622      0.656666      0.749026  6.325298e-01
# max        0.981424      0.958810      0.993502      1.000000  1.000000e+00
#
#        instrumentalness       valence        energy
# count      28372.000000  28372.000000  28372.000000
# mean           0.080049      0.532864      0.569875
# std            0.211245      0.250972      0.244385
# min            0.000000      0.000000      0.000000
# 25%            0.000000      0.329143      0.380361
# 50%            0.000085      0.539365      0.580567
# 75%            0.009335      0.738252      0.772766
# max            0.996964      1.000000      1.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# ## Boxplots para a demonstração do comportamento das variáveis.

# %% [markdown]
# Boxplot sobre a violência verbal das músicas

# %%
sns.boxplot(y = "violence",data = df)
# Out:
# <AxesSubplot:ylabel='violence'>

# %% [markdown]
# Boxplot sobre a dançabilidade das músicas

# %%
sns.boxplot(y = "danceability", data=df)
# Out:
# <AxesSubplot:ylabel='danceability'>

# %% [markdown]
# Boxplot sobre a positividade das músicas

# %%
sns.boxplot(y = "valence", data=df)
# Out:
# <AxesSubplot:ylabel='valence'>

# %% [markdown]
# Boxplot sobre a energia das músicas

# %%
sns.boxplot(y = "energy", data=df)
# Out:
# <AxesSubplot:ylabel='energy'>

# %% [markdown]
# Boxplot da relação da violência verbal de cada gênero musical

# %%
sns.boxplot(data = df, x = 'genre', y = 'violence', whis = 2, width  = 0.7)
# Out:
# <AxesSubplot:xlabel='genre', ylabel='violence'>

# %% [markdown]
# ## Índices de correlação entre as características musicais

# %% [markdown]
# Aqui é possível analisar quais características musicais tem mais/menos correlação entre si.

# %%
corr = df.corr().round(decimals = 4)
corr
# Out:
#                           dating  violence  world/life  night/time  \
# dating                    1.0000   -0.1074     -0.0737      0.0345
# violence                 -0.1074    1.0000     -0.1868     -0.1243
# world/life               -0.0737   -0.1868      1.0000     -0.1162
# night/time                0.0345   -0.1243     -0.1162      1.0000
# shake the audience        0.0270   -0.0279     -0.0535     -0.0088
# family/gospel             0.0098   -0.0335     -0.0395     -0.0135
# romantic                  0.0346   -0.1554     -0.0719     -0.0396
# communication            -0.0575   -0.0759     -0.0698     -0.0420
# obscene                  -0.0205   -0.1597     -0.2114     -0.1168
# music                    -0.0092   -0.1591     -0.1286     -0.0705
col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_4a690_row2_col8, #T_4a690_row2_col16, #T_4a690_row7_col0, #T_4a690_row9_col13, #T_4a690_row13_col5, #T_4a690_row15_col12, #T_4a690_row16_col19, #T_4a690_row17_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_4a690_row2_col11, #T_4a690_row3_col8, #T_4a690_row7_col1, #T_4a690_row9_col10, #T_4a690_row9_col14, #T_4a690_row15_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_4a690_row2_col17, #T_4a690_row17_col8, #T_4a690_row20_col18 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_4a690_row2_col18, #T_4a690_row8_col17 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #

# %% [markdown]
# Aqui foi feita a análise dos índices de correlação com exclusão da diagonal principal, haja vista que ela faz correlação consigo mesma, logo não faria sentido analisar esses dados. No caso, ela foi preenchida com o valor de 0, após isso, foi feito a análise a partir dos novos valores.

# %%
np.fill_diagonal(corr.values, 0)
corr
# Out:
#                           dating  violence  world/life  night/time  \
# dating                    0.0000   -0.1074     -0.0737      0.0345
# violence                 -0.1074    0.0000     -0.1868     -0.1243
# world/life               -0.0737   -0.1868      0.0000     -0.1162
# night/time                0.0345   -0.1243     -0.1162      0.0000
# shake the audience        0.0270   -0.0279     -0.0535     -0.0088
# family/gospel             0.0098   -0.0335     -0.0395     -0.0135
# romantic                  0.0346   -0.1554     -0.0719     -0.0396
# communication            -0.0575   -0.0759     -0.0698     -0.0420
# obscene                  -0.0205   -0.1597     -0.2114     -0.1168
# music                    -0.0092   -0.1591     -0.1286     -0.0705
# movement/places          -0.0780   -0.0184     -0.0803     -0.0428
# light/visual perceptions -0.0885   -0.0017     -0.0175     -0.0448
# family/spiritual         -0.0633    0.0718      0.0230     -0.0619
# like/girls                0.0043   -0.0644     -0.0423     -0.0190
# sadness                  -0.0129   -0.2211     -0.1595     -0.1039
# feelings                  0.0258   -0.0814     -0.0534     -0.0002
# danceability              0.0372   -0.0972     -0.0713      0.0057
# loudness                  0.0006    0.1286     -0.0492     -0.0002
# acousticness              0.0220   -0.1896      0.0379     -0.0113
# instrumentalness         -0.0211    0.1056     -0.0167     -0.0001
# valence                   0.0781   -0.0700     -0.0864      0.0311
# energy                    0.0037    0.2049     -0.0764      0.0125
#
#                           shake the audience  family/gospel  romantic  \
# dating                                0.0270         0.0098    0.0346
# violence                             -0.0279        -0.0335   -0.1554
# world/life                           -0.0535        -0.0395   -0.0719
# night/time                           -0.0088        -0.0135   -0.0396
# shake the audience                    0.0000        -0.0049   -0.0390
# family/gospel                        -0.0049         0.0000   -0.0125
# romantic                             -0.0390        -0.0125    0.0000
# communication                        -0.0555        -0.0632   -0.0200
# obscene                               0.0738        -0.0062   -0.1586
# music                                -0.0426         0.0102   -0.0410
# movement/places                      -0.0366        -0.0068   -0.0989
# light/visual perceptions             -0.0786        -0.0693   -0.0010
# family/spiritual                     -0.0351         0.0032   -0.0622
# like/girls                            0.0034        -0.0215    0.0005
# sadness                              -0.0753        -0.0508   -0.0446
# feelings                              0.0127        -0.0063   -0.0221
# danceability                          0.0548         0.0323   -0.0777
# loudness                              0.0985        -0.0433   -0.1451
# acousticness                         -0.1003         0.0485    0.2221
# instrumentalness                     -0.0137        -0.0048   -0.0260
# valence                               0.0523         0.0459   -0.0372
# energy                                0.1042        -0.0393   -0.1976
#
#                           communication  obscene   music  ...  \
# dating                          -0.0575  -0.0205 -0.0092  ...
# violence                        -0.0759  -0.1597 -0.1591  ...
# world/life                      -0.0698  -0.2114 -0.1286  ...
# night/time                      -0.0420  -0.1168 -0.0705  ...
# shake the audience              -0.0555   0.0738 -0.0426  ...
# family/gospel                   -0.0632  -0.0062  0.0102  ...
# romantic                        -0.0200  -0.1586 -0.0410  ...
# communication                    0.0000  -0.0778 -0.0793  ...
# obscene                         -0.0778   0.0000 -0.1338  ...
# music                           -0.0793  -0.1338  0.0000  ...
# movement/places                 -0.1480   0.0522 -0.0132  ...
# light/visual perceptions        -0.1541  -0.1332  0.0331  ...
# family/spiritual                -0.0909  -0.0765  0.0180  ...
# like/girls                      -0.0691   0.0095 -0.0268  ...
# sadness                         -0.0059  -0.2661 -0.1148  ...
# feelings                        -0.0092  -0.0754 -0.0452  ...
# danceability                     0.0069   0.2734 -0.0413  ...
# loudness                         0.0026   0.1380 -0.1350  ...
# acousticness                     0.0125  -0.1580  0.1621  ...
# instrumentalness                -0.0447  -0.0029  0.0086  ...
# valence                          0.0002   0.1535 -0.0030  ...
# energy                          -0.0210   0.1567 -0.1458  ...
#
#                           family/spiritual  like/girls  sadness  feelings  \
# dating                             -0.0633      0.0043  -0.0129    0.0258
# violence                            0.0718     -0.0644  -0.2211   -0.0814
# world/life                          0.0230     -0.0423  -0.1595   -0.0534
# night/time                         -0.0619     -0.0190  -0.1039   -0.0002
# shake the audience                 -0.0351      0.0034  -0.0753    0.0127
# family/gospel                       0.0032     -0.0215  -0.0508   -0.0063
# romantic                           -0.0622      0.0005  -0.0446   -0.0221
# communication                      -0.0909     -0.0691  -0.0059   -0.0092
# obscene                            -0.0765      0.0095  -0.2661   -0.0754
# music                               0.0180     -0.0268  -0.1148   -0.0452
# movement/places                    -0.0470     -0.0580  -0.1197   -0.0576
# light/visual perceptions           -0.0213     -0.0748  -0.0425   -0.0648
# family/spiritual                    0.0000     -0.0640  -0.0608   -0.0399
# like/girls                         -0.0640      0.0000  -0.0586    0.0077
# sadness                            -0.0608     -0.0586   0.0000   -0.0653
# feelings                           -0.0399      0.0077  -0.0653    0.0000
# danceability                       -0.0030      0.0467  -0.0916    0.0166
# loudness                           -0.0332      0.0235  -0.0580    0.0034
# acousticness                        0.0083     -0.0193   0.0924   -0.0034
# instrumentalness                    0.0207     -0.0160  -0.0467    0.0107
# valence                             0.0040      0.0405  -0.0875    0.0405
# energy                             -0.0185      0.0165  -0.1105    0.0090
#
#                           danceability  loudness  acousticness  \
# dating                          0.0372    0.0006        0.0220
# violence                       -0.0972    0.1286       -0.1896
# world/life                     -0.0713   -0.0492        0.0379
# night/time                      0.0057   -0.0002       -0.0113
# shake the audience              0.0548    0.0985       -0.1003
# family/gospel                   0.0323   -0.0433        0.0485
# romantic                       -0.0777   -0.1451        0.2221
# communication                   0.0069    0.0026        0.0125
# obscene                         0.2734    0.1380       -0.1580
# music                          -0.0413   -0.1350        0.1621
# movement/places                 0.0509    0.0171       -0.0317
# light/visual perceptions       -0.0895   -0.0790        0.0692
# family/spiritual               -0.0030   -0.0332        0.0083
# like/girls                      0.0467    0.0235       -0.0193
# sadness                        -0.0916   -0.0580        0.0924
# feelings                        0.0166    0.0034       -0.0034
# danceability                    0.0000    0.0414       -0.1235
# loudness                        0.0414    0.0000       -0.5397
# acousticness                   -0.1235   -0.5397        0.0000
# instrumentalness               -0.0833   -0.1325        0.0078
# valence                         0.4936    0.1335       -0.1729
# energy                          0.0163    0.7731       -0.7200
#
#                           instrumentalness  valence  energy
# dating                             -0.0211   0.0781  0.0037
# violence                            0.1056  -0.0700  0.2049
# world/life                         -0.0167  -0.0864 -0.0764
# night/time                         -0.0001   0.0311  0.0125
# shake the audience                 -0.0137   0.0523  0.1042
# family/gospel                      -0.0048   0.0459 -0.0393
# romantic                           -0.0260  -0.0372 -0.1976
# communication                      -0.0447   0.0002 -0.0210
# obscene                            -0.0029   0.1535  0.1567
# music                               0.0086  -0.0030 -0.1458
# movement/places                    -0.0210   0.0805  0.0472
# light/visual perceptions            0.0370  -0.0858 -0.0764
# family/spiritual                    0.0207   0.0040 -0.0185
# like/girls                         -0.0160   0.0405  0.0165
# sadness                            -0.0467  -0.0875 -0.1105
# feelings                            0.0107   0.0405  0.0090
# danceability                       -0.0833   0.4936  0.0163
# loudness                           -0.1325   0.1335  0.7731
# acousticness                        0.0078  -0.1729 -0.7200
# instrumentalness                    0.0000  -0.0773  0.0056
# valence                            -0.0773   0.0000  0.2805
# energy                              0.0056   0.2805  0.0000
#
# [22 rows x 22 columns]

# %% [markdown]
# Abaixo estão os índices de correlação mais/menos fortes após o tratamento.

# %%
corr.max()
# Out:
# dating                      0.0781
# violence                    0.2049
# world/life                  0.0379
# night/time                  0.0345
# shake the audience          0.1042
# family/gospel               0.0485
# romantic                    0.2221
# communication               0.0125
# obscene                     0.2734
# music                       0.1621
# movement/places             0.0805
# light/visual perceptions    0.0692
# family/spiritual            0.0718
# like/girls                  0.0467
# sadness                     0.0924
# feelings                    0.0405
# danceability                0.4936
# loudness                    0.7731
# acousticness                0.2221
# instrumentalness            0.1056
# valence                     0.4936
# energy                      0.7731
# dtype: float64

# %%
corr.min()
# Out:
# dating                     -0.1074
# violence                   -0.2211
# world/life                 -0.2114
# night/time                 -0.1243
# shake the audience         -0.1003
# family/gospel              -0.0693
# romantic                   -0.1976
# communication              -0.1541
# obscene                    -0.2661
# music                      -0.1591
# movement/places            -0.1480
# light/visual perceptions   -0.1541
# family/spiritual           -0.0909
# like/girls                 -0.0748
# sadness                    -0.2661
# feelings                   -0.0814
# danceability               -0.1235
# loudness                   -0.5397
# acousticness               -0.7200
# instrumentalness           -0.1325
# valence                    -0.1729
# energy                     -0.7200
# dtype: float64

# %% [markdown]
# ## K_Means

# %% [markdown]
# - Antes, foi feita a filtração de algumas colunas do dataframe que não seriam úteis para tal análise:

# %%
unecessary = ["genre", "lyrics", "dating", "violence", "world/life", "night/time", "shake the audience", "family/gospel",
"sadness", "feelings", "danceability", "loudness", "instrumentalness", "valence", "topic",
"romantic", "communication", "obscene", "music", "movement/places", "light/visual perceptions", "family/spiritual", "like/girls"]
df.drop(unecessary, axis = "columns", inplace = True)

# %%
df
# Out:
#                 artist_name                     track_name  acousticness  \
# 0                    mukesh           mohabbat bhi jhoothi      0.997992
# 1             frankie laine                      i believe      0.954819
# 2               johnnie ray                            cry      0.840361
# 3               pérez prado                       patricia      0.083935
# 4      giorgos papadopoulos             apopse eida oneiro      0.975904
# ...                     ...                            ...           ...
# 28367               mack 10                10 million ways      0.062549
# 28368                m.o.p.  ante up (robbin hoodz theory)      0.004607
# 28369                  nine                  whutcha want?      0.104417
# 28370            will smith                         switch      0.007027
# 28371                 jeezy                         r.i.p.      0.015862
#
#          energy
# 0      0.137110
# 1      0.263240
# 2      0.139112
# 3      0.743736
# 4      0.394375
# ...         ...
# 28367  0.695686
# 28368  0.797791
# 28369  0.767761
# 28370  0.885882
# 28371  0.492477
#
# [28372 rows x 4 columns]

# %% [markdown]
# A dsitribuição desses dados:

# %%
plt.scatter(df["acousticness"], df["energy"], alpha = 0.6)

# %% [markdown]
# Primeiramente foi definido a quantia de "Clusters", ou grupos, desejados para fazer o agrupamento:

# %%
km = KMeans(n_clusters = 4)

# %% [markdown]
# Abaixo já é exibido uma lista esses grupos separados de acordo com a similaridade entre si:

# %%
y_predicted = km.fit_predict(df[["acousticness", "energy"]])
y_predicted
# Out:
# array([1, 1, 1, ..., 0, 0, 2], dtype=int32)

# %% [markdown]
# Após isso foi inserida uma nova coluna com esses valores no DataFrame:

# %%
df["cluster"] = y_predicted
df.head()
# Out:
#             artist_name            track_name  acousticness    energy  cluster
# 0                mukesh  mohabbat bhi jhoothi      0.997992  0.137110        1
# 1         frankie laine             i believe      0.954819  0.263240        1
# 2           johnnie ray                   cry      0.840361  0.139112        1
# 3           pérez prado              patricia      0.083935  0.743736        0
# 4  giorgos papadopoulos    apopse eida oneiro      0.975904  0.394375        1

# %% [markdown]
# Com os agrupamentos feitos, foi possível fazer um gráfico de dispersão mostrando esse diferentes grupos:

# %%
df1 = df[df["cluster"] == 0 ]
df2 = df[df["cluster"] == 1 ]
df3 = df[df["cluster"] == 2 ]
df4 = df[df["cluster"] == 3 ]

plt.scatter(df1["acousticness"], df1["energy"], color = "darkblue")
plt.scatter(df2["acousticness"], df2["energy"], color = "lightgreen")
plt.scatter(df3["acousticness"], df3["energy"], color = "red")
plt.scatter(df4["acousticness"], df4["energy"], color = "grey")

plt.ylabel("acousticness")
plt.xlabel("energy")

plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - Se atente que os agrupamentos podem não ser os melhores possíveis.

# %% [markdown]
# Abaixo estão as coordenadas dos 4 centróides que serão inseridos no gráfico:

# %%
km.cluster_centers_
# Out:
# array([[0.06510002, 0.83095411],
#        [0.83879675, 0.24543459],
#        [0.13806696, 0.52145657],
#        [0.54609529, 0.51910281]])

# %%
df1 = df[df["cluster"] == 0 ]
df2 = df[df["cluster"] == 1 ]
df3 = df[df["cluster"] == 2 ]
df4 = df[df["cluster"] == 3 ]

plt.scatter(df1["acousticness"], df1["energy"], color = "darkblue")
plt.scatter(df2["acousticness"], df2["energy"], color = "lightgreen")
plt.scatter(df3["acousticness"], df3["energy"], color = "red")
plt.scatter(df4["acousticness"], df4["energy"], color = "grey")

plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1], color = "black", marker = "^", label = "centroid")

plt.ylabel("acousticness")
plt.xlabel("energy")

plt.legend()

# %% [markdown]
# Todavia, após todo este processo, fica a dúvida: "Será que o melhor número de agrupamentos possíveis é realmente 4?"
# - Para isso, existe o "Elbow Method", ou método do cotovelo, que define o melhor número para K, em que K representa a quantia de agrupamentos.

# %% [markdown]
# Agora para definir o melhor valor para K (Elbow_method):

# %%
k_range = range(1,10)
sse = []

for k in k_range:
    km = KMeans(n_clusters = k)
    km.fit(df[["energy", "acousticness"]])
    sse.append(km.inertia_)

# %% [markdown]
# Observe os valores abaixo da lista dos erros médios quadrados, em que há um rápido declinio sobre os dois primeiros valores, e em que a partir do terceiro valor todos os outros subsequentes seguem um padrão praticamente igual.
# - Dessa forma, o valor indicado para K é igual a 2.

# %%
sse
# Out:
# [4722.813836331869,
#  1501.1626167020752,
#  1011.1452306906885,
#  713.4335551706463,
#  582.7476821326923,
#  479.0751410200106,
#  405.01835231263715,
#  353.22482283876155,
#  314.6622036427087]

# %% [markdown]
# Não somente, o gráfico abaixo, apesar de não ser tão claro nesse caso, demonstra esse comportamento:

# %%
plt.xlabel("K")
plt.ylabel("Soma dos erros quadrados (SSE)")
plt.plot(k_range, sse)

# %% [markdown]
#     Logo, o gráfico mais adequado para esse conjunto de dados não é igual ao que foi feito anteriormente, o ideal é feito com o valor de K igual a 2, em que existem dois conjuntos de músicas que se assemelham ao se tratar sobre a energia relacionada com a acústica de cada música.

# %% [markdown]
# Então, é preciso reajustar alguns dados:

# %% [markdown]
# Definiir a quantia de agrupamentos para 2:

# %%
km = KMeans(n_clusters = 2)

# %% [markdown]
# Dividir o DataFrame em 2 conjuntos:

# %%
y_predicted = km.fit_predict(df[["acousticness", "energy"]])

# %% [markdown]
# Redesignar esses novos grupos na coluna "cluster" no DataFrame:

# %%
df["cluster"] = y_predicted

# %%
df1 = df[df["cluster"] == 0 ]
df2 = df[df["cluster"] == 1 ]

plt.scatter(df1["acousticness"], df1["energy"], color = "darkblue")
plt.scatter(df2["acousticness"], df2["energy"], color = "lightgreen")

plt.ylabel("acousticness")
plt.xlabel("energy")

plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1], color = "black", marker = "^", label = "centroid")

plt.legend()

# %% [markdown]
# Após o gráfico correto ter sido feito, é preciso checar se tais grupos realmente têm características em comum:

# %%
df = df.sort_values(by="cluster", ascending=False)
clstr0 = df[df["cluster"] == 0]
clstr1 = df[df["cluster"] == 1]

# %%
clstr0.describe()
# Out:
#        acousticness        energy  cluster
# count  1.796100e+04  17961.000000  17961.0
# mean   1.181563e-01      0.700041      0.0
# std    1.317526e-01      0.177201      0.0
# min    2.811248e-07      0.080652      0.0
# 25%    9.717881e-03      0.571558      0.0
# 50%    6.475810e-02      0.712704      0.0
# 75%    1.947783e-01      0.845841      0.0
# max    6.596382e-01      1.000000      0.0

# %%
clstr1.describe()
# Out:
#        acousticness        energy  cluster
# count  10411.000000  10411.000000  10411.0
# mean       0.720638      0.345313      1.0
# std        0.176499      0.170087      0.0
# min        0.203814      0.000000      1.0
# 25%        0.585341      0.220196      1.0
# 50%        0.740964      0.330309      1.0
# 75%        0.869478      0.454437      1.0
# max        1.000000      0.991992      1.0
